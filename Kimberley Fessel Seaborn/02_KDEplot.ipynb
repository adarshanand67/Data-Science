# %% [markdown]
# # Seaborn: KDEplot

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
cars = sns.load_dataset('mpg').dropna()

cars.shape
# Out:
# (392, 9)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ## Intro Visuals

# %%
hp = cars.horsepower
hp
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 392, dtype: float64

# %%
sns.set_style('white')
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)

# %%
plt.figure(figsize=(8,5))
sns.displot(hp, kde=False)

sns.despine(left=True)
plt.xlim(0, 280)
plt.xlabel('')
plt.yticks([])
plt.tight_layout(); # Fit the figure to the window

# %%
plt.figure(figsize=(8,5))
sns.distplot(hp, kde_kws={"lw": 5}, hist_kws={'alpha': 0.25})
# alpha -> opacity (0->Transparent, 1->Opaque)
# zorder -> z-order of the plot (which part shows on top)

sns.despine(left=True)
plt.xlim(0, 280)
plt.xlabel('')
plt.yticks([])
plt.tight_layout();
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(hp, shade=True, color='r',bw_method=0.1)
# bw_method -> bandwidth method (0->Scott, 1->Silverman)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(hp, shade=True, color='r',bw_method=0.5,cumulative=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %% [markdown]
# ## "How It Works" Visuals

# %%
import numpy as np
import scipy.stats as stats

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
blue, orange, green, red = sns.color_palette()[:4]
blue
# Out:
# (0.12156862745098039, 0.4666666666666667, 0.7058823529411765)

# %%
pts = [1, 3, 3.5, 4, 6, 8]

# %%
plt.figure(figsize=(8, 5))
plt.scatter(pts, [0]*len(pts), s=100, zorder=1)
plt.axhline(0, color='gray', zorder=0) #axhline(y, xmin, xmax, color, zorder) -> horizontal line
plt.ylim(-0.1, 1.5)
plt.xlim(-3, 12)

plt.box(False)
plt.xticks(range(9))
plt.yticks([])
plt.tight_layout();

# %%
for i in range(len(pts)):
    plt.figure(figsize=(8, 5))
    for point in pts[0:i+1]:
        mu = point
        variance = 1
        sigma = np.sqrt(variance)
        x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
        plt.plot(x, stats.norm.pdf(x, mu, sigma), linestyle='--', color='gray', zorder=2)
    plt.scatter(pts, [0]*len(pts), s=100, zorder=1)
    plt.axhline(0, color='gray', zorder=0)
    plt.xlim(-3, 12)
    plt.ylim(-0.1, 1.5)
    plt.box(False)
    plt.xticks(range(9))
    plt.yticks([])
    plt.tight_layout();
# Out:
# (-3.0, 12.0)
# (-0.1, 1.5)
# ([<matplotlib.axis.XTick at 0x1b2694c9220>,
#   <matplotlib.axis.XTick at 0x1b2694c91f0>,
#   <matplotlib.axis.XTick at 0x1b266e05f40>,
#   <matplotlib.axis.XTick at 0x1b269501730>,
#   <matplotlib.axis.XTick at 0x1b269501e80>,
#   <matplotlib.axis.XTick at 0x1b269501ee0>,
#   <matplotlib.axis.XTick at 0x1b269502250>,
#   <matplotlib.axis.XTick at 0x1b269502d60>,
#   <matplotlib.axis.XTick at 0x1b26950f4f0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# ([], [])
# (-3.0, 12.0)
# (-0.1, 1.5)
# ([<matplotlib.axis.XTick at 0x1b269517820>,
#   <matplotlib.axis.XTick at 0x1b2695177f0>,
#   <matplotlib.axis.XTick at 0x1b26950f460>,
#   <matplotlib.axis.XTick at 0x1b269561220>,
#   <matplotlib.axis.XTick at 0x1b269561970>,
#   <matplotlib.axis.XTick at 0x1b269564100>,
#   <matplotlib.axis.XTick at 0x1b2695615b0>,
#   <matplotlib.axis.XTick at 0x1b2695646d0>,
#   <matplotlib.axis.XTick at 0x1b269564e20>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# ([], [])
# (-3.0, 12.0)
# (-0.1, 1.5)
# ([<matplotlib.axis.XTick at 0x1b2695762e0>,
#   <matplotlib.axis.XTick at 0x1b2695762b0>,
#   <matplotlib.axis.XTick at 0x1b269564b80>,
#   <matplotlib.axis.XTick at 0x1b2695b4970>,
#   <matplotlib.axis.XTick at 0x1b2695b5100>,
#   <matplotlib.axis.XTick at 0x1b2695b4be0>,
#   <matplotlib.axis.XTick at 0x1b2695b50d0>,
#   <matplotlib.axis.XTick at 0x1b2695c20a0>,
#   <matplotlib.axis.XTick at 0x1b2695c2760>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# ([], [])
# (-3.0, 12.0)
# (-0.1, 1.5)
# ([<matplotlib.axis.XTick at 0x1b2695d0a60>,
#   <matplotlib.axis.XTick at 0x1b2695d0a30>,
#   <matplotlib.axis.XTick at 0x1b2695d0160>,
#   <matplotlib.axis.XTick at 0x1b269618940>,
#   <matplotlib.axis.XTick at 0x1b269618be0>,
#   <matplotlib.axis.XTick at 0x1b26961c460>,
#   <matplotlib.axis.XTick at 0x1b26961cbb0>,
#   <matplotlib.axis.XTick at 0x1b269620340>,
#   <matplotlib.axis.XTick at 0x1b269620a90>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# ([], [])
# (-3.0, 12.0)
# (-0.1, 1.5)
# ([<matplotlib.axis.XTick at 0x1b26962eaf0>,
#   <matplotlib.axis.XTick at 0x1b26962eac0>,
#   <matplotlib.axis.XTick at 0x1b26962e1f0>,
#   <matplotlib.axis.XTick at 0x1b26a644730>,
#   <matplotlib.axis.XTick at 0x1b26a644e80>,
#   <matplotlib.axis.XTick at 0x1b26a645610>,
#   <matplotlib.axis.XTick at 0x1b26a645d60>,
#   <matplotlib.axis.XTick at 0x1b26a64f4f0>,
#   <matplotlib.axis.XTick at 0x1b26a645a00>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# ([], [])
# (-3.0, 12.0)
# (-0.1, 1.5)
# ([<matplotlib.axis.XTick at 0x1b26a65dd60>,
#   <matplotlib.axis.XTick at 0x1b26a65dd30>,
#   <matplotlib.axis.XTick at 0x1b26a65d460>,
#   <matplotlib.axis.XTick at 0x1b26a69bd60>,
#   <matplotlib.axis.XTick at 0x1b26a6a24f0>,
#   <matplotlib.axis.XTick at 0x1b26a69bdc0>,
#   <matplotlib.axis.XTick at 0x1b26a6a2040>,
#   <matplotlib.axis.XTick at 0x1b26a6b2460>,
#   <matplotlib.axis.XTick at 0x1b26a6b2bb0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# ([], [])

# %%
for i in range(1, len(pts)+1):
    plt.figure(figsize=(8, 5))
    for point in pts[0:len(pts)+1]:
        mu = point
        variance = 1
        sigma = np.sqrt(variance)
        x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
        plt.plot(x, stats.norm.pdf(x, mu, sigma), linestyle='--', color='gray', zorder=2)
    plt.scatter(pts, [0]*len(pts), s=100, zorder=1)
    plt.axhline(0, color='gray', zorder=0)

    total_x = np.linspace(pts[0] - 3*sigma, pts[i-1] + 3*sigma, 1000)
    total = sum([stats.norm.pdf(total_x, pts[j], sigma) for j in range(i)])
    plt.plot(total_x, total, color=blue, lw=3)
    plt.xlim(-3, 12)
    plt.ylim(-0.1, 1.5)
    plt.box(False)
    plt.xticks(range(9))
    plt.yticks([])
    plt.tight_layout();
    #plt.savefig(f'02KDE_addkernel{i}.svg');
# Out:
# (-3.0, 12.0)
# (-0.1, 1.5)
# ([<matplotlib.axis.XTick at 0x1b269638cd0>,
#   <matplotlib.axis.XTick at 0x1b269638a00>,
#   <matplotlib.axis.XTick at 0x1b2695d0550>,
#   <matplotlib.axis.XTick at 0x1b2695172e0>,
#   <matplotlib.axis.XTick at 0x1b269517c70>,
#   <matplotlib.axis.XTick at 0x1b2695c2850>,
#   <matplotlib.axis.XTick at 0x1b2695c2250>,
#   <matplotlib.axis.XTick at 0x1b2695b43d0>,
#   <matplotlib.axis.XTick at 0x1b2695c2a90>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# ([], [])
# (-3.0, 12.0)
# (-0.1, 1.5)
# ([<matplotlib.axis.XTick at 0x1b2695617f0>,
#   <matplotlib.axis.XTick at 0x1b2695617c0>,
#   <matplotlib.axis.XTick at 0x1b2695616a0>,
#   <matplotlib.axis.XTick at 0x1b26947f8b0>,
#   <matplotlib.axis.XTick at 0x1b26947f2e0>,
#   <matplotlib.axis.XTick at 0x1b269476880>,
#   <matplotlib.axis.XTick at 0x1b269476400>,
#   <matplotlib.axis.XTick at 0x1b269469910>,
#   <matplotlib.axis.XTick at 0x1b269476460>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# ([], [])
# (-3.0, 12.0)
# (-0.1, 1.5)
# ([<matplotlib.axis.XTick at 0x1b26938ac70>,
#   <matplotlib.axis.XTick at 0x1b26938adf0>,
#   <matplotlib.axis.XTick at 0x1b269450130>,
#   <matplotlib.axis.XTick at 0x1b266e753a0>,
#   <matplotlib.axis.XTick at 0x1b266e75d30>,
#   <matplotlib.axis.XTick at 0x1b268edfc10>,
#   <matplotlib.axis.XTick at 0x1b268edf730>,
#   <matplotlib.axis.XTick at 0x1b268f343d0>,
#   <matplotlib.axis.XTick at 0x1b268edf670>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# ([], [])
# (-3.0, 12.0)
# (-0.1, 1.5)
# ([<matplotlib.axis.XTick at 0x1b266eaadf0>,
#   <matplotlib.axis.XTick at 0x1b266eaaf40>,
#   <matplotlib.axis.XTick at 0x1b268ed1070>,
#   <matplotlib.axis.XTick at 0x1b269012820>,
#   <matplotlib.axis.XTick at 0x1b269012e80>,
#   <matplotlib.axis.XTick at 0x1b268ec96a0>,
#   <matplotlib.axis.XTick at 0x1b26a6cb880>,
#   <matplotlib.axis.XTick at 0x1b2694b9970>,
#   <matplotlib.axis.XTick at 0x1b268ec9f70>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# ([], [])
# (-3.0, 12.0)
# (-0.1, 1.5)
# ([<matplotlib.axis.XTick at 0x1b26a64f7f0>,
#   <matplotlib.axis.XTick at 0x1b26a64f970>,
#   <matplotlib.axis.XTick at 0x1b269627f10>,
#   <matplotlib.axis.XTick at 0x1b269629dc0>,
#   <matplotlib.axis.XTick at 0x1b266e9d550>,
#   <matplotlib.axis.XTick at 0x1b266e9dca0>,
#   <matplotlib.axis.XTick at 0x1b266ea2430>,
#   <matplotlib.axis.XTick at 0x1b266ea2b80>,
#   <matplotlib.axis.XTick at 0x1b266ea2820>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# ([], [])
# (-3.0, 12.0)
# (-0.1, 1.5)
# ([<matplotlib.axis.XTick at 0x1b266e8c400>,
#   <matplotlib.axis.XTick at 0x1b266e8c3d0>,
#   <matplotlib.axis.XTick at 0x1b266e98070>,
#   <matplotlib.axis.XTick at 0x1b269573700>,
#   <matplotlib.axis.XTick at 0x1b269573e50>,
#   <matplotlib.axis.XTick at 0x1b2695545e0>,
#   <matplotlib.axis.XTick at 0x1b269554d30>,
#   <matplotlib.axis.XTick at 0x1b26957f4c0>,
#   <matplotlib.axis.XTick at 0x1b269554970>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# ([], [])

# %%
plt.figure(figsize=(8,5))
plt.plot(total_x, total, color=blue, lw=3)
plt.scatter(pts, [0]*len(pts), s=100, zorder=1, alpha=0.5)
plt.axhline(0, color='gray', zorder=0)
plt.xlim(-3, 12)
plt.ylim(-0.1, 1.5)
plt.box(False)
plt.xticks(range(9))
plt.yticks([])
plt.tight_layout();

# %% [markdown]
# ### Other Kernels

# %%
plt.figure(figsize=(8, 5))

mu = pts[3]
variance = 1
sigma = np.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma), linestyle='--', color='gray', zorder=2)

plt.scatter(pts[3], [0], s=200, zorder=1)
plt.axhline(0, color='gray', zorder=0)
plt.ylim(-0.1, .5)
plt.box(False)
plt.xticks([])
plt.yticks([])
plt.tight_layout();

# %%
plt.figure(figsize=(8, 5))

def build_tri_kernel(x, center=0, sigma=1):
    m = 0.4/sigma
    if x < (center-sigma):
        return 0
    elif x < center:
        return m*x + m*(sigma-center)
    elif x < (center+sigma):
        return -m*x + m*(sigma + center)
    else:
        return 0  

mu = pts[3]
variance = 1
sigma = np.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, [build_tri_kernel(val, center=mu, sigma=1.5) for val in x], 
         linestyle='--', color='gray', zorder=2)
plt.scatter(pts[3], [0], s=200, zorder=1)
plt.axhline(0, color='gray', zorder=0)
plt.ylim(-0.1, .5)
plt.box(False)
plt.xticks([])
plt.yticks([])
plt.tight_layout();

# %%
plt.figure(figsize=(8, 5))

def build_cos_kernel(x, center=0, sigma=1):
    if np.abs(x - center) < sigma:
        return 0.4*np.cos(x-center)
    else:
        return 0  

mu = pts[3]
variance = 1
sigma = np.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, [build_cos_kernel(val, center=mu, sigma=1.5) for val in x], 
         linestyle='--', color='gray', zorder=2)
plt.scatter(pts[3], [0], s=200, zorder=1)
plt.axhline(0, color='gray', zorder=0)
plt.ylim(-0.1, .5)
plt.box(False)
plt.xticks([])
plt.yticks([])
plt.tight_layout();

# %% [markdown]
# ## Univariate (1D)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.kdeplot(cars.horsepower);
# KDE plot - Used for frequency distribution of data

# %%
sns.kdeplot(cars.horsepower, shade=True);

# %%
sns.kdeplot(cars.horsepower, bw_method=0.5);
# bw_method - bandwidth method
# Lesser the bandwidth, lesser the smoothness

# %%
sns.kdeplot(cars.horsepower, cumulative=True);

# %% [markdown]
# ### Bandwidth Widget

# %%
from ipywidgets import interact, interactive, HBox, VBox, interactive_output

from IPython.display import display

# %%
def bandwidth_widget(bw=10):
    sns.kdeplot(cars.horsepower, bw_method=bw, lw=3, shade=True)
    plt.xlim(-30, 300)
    plt.ylim(0, 0.02)

# %%
interactive(bandwidth_widget, bw=(0.1, 30, 0.5))
# Out:
# interactive(children=(FloatSlider(value=10.0, description='bw', max=30.0, min=0.1, step=0.5), Output()), _dom_…

# %% [markdown]
# ## Bivariate (2D)

# %% [markdown]
# ### Bivariate Intro

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.set_style('whitegrid')
# mpg - miles per gallon

# %%
#sns.kdeplot(cars.horsepower, cars.mpg)
sns.scatterplot(x=cars.horsepower, y=cars.mpg, color='black', alpha=0.8)
plt.xlim(0, 260)
plt.ylim(0, 55)
plt.xlabel('Horsepower', fontsize=16)
plt.ylabel('MPG', fontsize=16)
plt.tight_layout();

# %%
sns.kdeplot(x=cars.horsepower, y=cars.mpg,color='black', shade=False, alpha=0.8)
sns.scatterplot(x=cars.horsepower, y=cars.mpg, color='purple', alpha=0.7, s=20, zorder=10)
plt.xlim(0, 260)
plt.ylim(0, 55)
plt.title('Horsepower vs MPG', fontsize=16)
plt.xlabel('Horsepower', fontsize=14)
plt.ylabel('MPG', fontsize=14)
plt.tight_layout();

# %%
sns.kdeplot(cars.horsepower, cars.mpg,cbar=True)
#sns.scatterplot(cars.horsepower, cars.mpg, color='black', alpha=0.7, s=20, zorder=10)
plt.xlim(0, 260)
plt.ylim(0, 55)
plt.xlabel('Horsepower', fontsize=14)
plt.ylabel('MPG', fontsize=14)
plt.tight_layout();
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Bivariate Demo

# %%
sns.kdeplot(cars.horsepower, cars.mpg);
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.kdeplot(cars.horsepower, cars.mpg, n_levels=20);
# More refined code
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.kdeplot(cars.horsepower, cars.mpg, shade=True);
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set_style('whitegrid')

sns.kdeplot(cars.horsepower, cars.mpg, 
            shade=True,
            shade_lowest=False
           );
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.kdeplot(cars.horsepower, cars.mpg, 
            shade=True, 
            shade_lowest=False,
            cbar=True
)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ## Bivariate KDEplot by Category

# %%
sns.set_style('whitegrid')

cyl_4 = cars[cars.cylinders==4]
cyl_8 = cars[cars.cylinders==8]

plt.figure(figsize=(8,6))

sns.kdeplot(cyl_4.horsepower, cyl_4.mpg,
            cmap="Blues", shade=True, shade_lowest=False)
sns.kdeplot(cyl_8.horsepower, cyl_8.mpg,
            cmap="Reds", shade=True, shade_lowest=False)

plt.xlabel('Horsepower', fontsize=14)
plt.ylabel('Miles per Gallon (MPG)', fontsize=14)

plt.annotate("4 Cylinders", (105, 32), color=blue, fontsize=16, fontweight='bold')
plt.annotate("8 Cylinders", (190, 18), color=red, fontsize=16, fontweight='bold');
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Other Figures that use KDE

# %%
plt.figure(figsize=(8,5))
sns.distplot(hp, kde_kws={"lw": 5}, hist_kws={'alpha': 0.25})

sns.despine(left=True)
plt.xlim(0, 280)
plt.xlabel('')
plt.yticks([])
plt.tight_layout();
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(cars[cars.cylinders.isin([4,6,8])], 
             hue='cylinders', 
             vars=['mpg', 'horsepower', 'acceleration'], 
             palette='rainbow',
            );

# %%
x=22
