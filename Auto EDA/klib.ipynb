# %% [markdown]
# ### https://towardsdatascience.com/speed-up-your-data-cleaning-and-preprocessing-with-klib-97191d320f80

# %% [markdown]
# # Use cases?
# - Missing values
# - Positive Correlation graphs
# - Negative Correlation graphs
# - Feature correlation plots wrt target

# %%
# !pip install klib

# %%
import klib
import pandas as pd
import seaborn as sns
import missingno as msno

# %%
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
klib.missingval_plot(df) # default representation of missing values, other settings such as sorting are available
# Out:
# GridSpec(6, 6)

# %%
klib.corr_plot(df, split='pos') # displaying only positive correlations, other settings include threshold, cmap...
# Out:
# Displaying positive correlations. Specify a positive "threshold" to limit the results further.
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.corr_plot(df, split='neg',) # displaying only negative correlations
# Out:
# Displaying negative correlations. Specify a negative "threshold" to limit the results further.
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.corr_plot(df,target='survived') # displaying only correlations with target variable
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.corr_mat(df) # default representation of a correlation matrix
# Out:
# <style type="text/css">
# #T_7545b_row0_col0, #T_7545b_row0_col4, #T_7545b_row0_col5, #T_7545b_row1_col1, #T_7545b_row1_col3, #T_7545b_row1_col4, #T_7545b_row1_col6, #T_7545b_row1_col7, #T_7545b_row2_col2, #T_7545b_row2_col5, #T_7545b_row2_col6, #T_7545b_row2_col7, #T_7545b_row3_col1, #T_7545b_row3_col3, #T_7545b_row3_col4, #T_7545b_row3_col5, #T_7545b_row4_col0, #T_7545b_row4_col1, #T_7545b_row4_col3, #T_7545b_row4_col4, #T_7545b_row4_col5, #T_7545b_row5_col0, #T_7545b_row5_col2, #T_7545b_row5_col3, #T_7545b_row5_col4, #T_7545b_row5_col5, #T_7545b_row6_col1, #T_7545b_row6_col2, #T_7545b_row6_col6, #T_7545b_row6_col7, #T_7545b_row7_col1, #T_7545b_row7_col2, #T_7545b_row7_col6, #T_7545b_row7_col7 {
#   color: None;
# }
# ...

# %%
klib.dist_plot(df) # default representation of a distribution plot, other settings include fill_range, histogram, ...
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %% [markdown]
# # Data cleaning

# %%
df_cleaned=klib.data_cleaning(df) # cleaning data, removing missing values, converting categorical variables to dummy variables, ...
# Out:
# Shape of cleaned data: (784, 15)Remaining NAs: 692
#
# Changes:
# Dropped rows: 107
#      of which 107 duplicates. (Rows: [47, 76, 77, 87, 95, 101, 121, 133, 173, 196, 198, 201, 213, 223, 241, 260, 274, 295, 300, 304, 313, 320, 324, 335, 343, 354, 355, 358, 359, 364, 368, 384, 409, 410, 413, 418, 420, 425, 428, 431, 454, 459, 464, 466, 470, 476, 481, 485, 488, 490, 494, 500, 511, 521, 522, 526, 531, 560, 563, 564, 568, 573, 588, 589, 598, 601, 612, 613, 614, 635, 636, 640, 641, 644, 646, 650, 656, 666, 674, 692, 696, 709, 732, 733, 734, 738, 739, 757, 758, 760, 773, 790, 792, 800, 808, 832, 837, 838, 844, 846, 859, 863, 870, 877, 878, 884, 886])
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 177
# Reduced memory by at least: 0.06 MB (-75.0%)

# %%
df.isna().sum() # checking missing values
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df_cleaned.info()
df_cleaned.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 784 entries, 0 to 783
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     784 non-null    int8
#  1   pclass       784 non-null    int8
#  2   sex          784 non-null    category
#  3   age          678 non-null    Float32
#  4   sibsp        784 non-null    int8
#  5   parch        784 non-null    int8
#  6   fare         784 non-null    Float32
#  7   embarked     782 non-null    category
#  8   class        784 non-null    category
#  9   who          784 non-null    category
#  10  adult_male   784 non-null    boolean
#  11  deck         202 non-null    category
#  12  embark_town  782 non-null    category
#  13  alive        784 non-null    category
#  14  alone        784 non-null    boolean
# dtypes: Float32(2), boolean(2), category(7), int8(4)
# memory usage: 20.4 KB
# survived         0
# pclass           0
# sex              0
# ...
