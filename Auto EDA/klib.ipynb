# %% [markdown]
# ### https://towardsdatascience.com/speed-up-your-data-cleaning-and-preprocessing-with-klib-97191d320f80

# %% [markdown]
# # Use cases?
# - Missing values
# - Positive Correlation graphs
# - Negative Correlation graphs
# - Feature correlation plots wrt target

# %%
# !pip install klib

# %%
import klib
import pandas as pd
import seaborn as sns
import missingno as msno

# %%
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
klib.missingval_plot(df) # default representation of missing values, other settings such as sorting are available
# Out:
# GridSpec(6, 6)

# %%
klib.corr_plot(df, split='pos') # displaying only positive correlations, other settings include threshold, cmap...
# Out:
# Displaying positive correlations. Specify a positive "threshold" to limit the results further.
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.corr_plot(df, split='neg') # displaying only negative correlations
# Out:
# Displaying negative correlations. Specify a negative "threshold" to limit the results further.
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.corr_plot(df,target='survived') # displaying only correlations with target variable
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.corr_mat(df) # default representation of a correlation matrix
# Out:
# <style type="text/css">
# #T_37489_row0_col0, #T_37489_row0_col4, #T_37489_row0_col5, #T_37489_row1_col1, #T_37489_row1_col3, #T_37489_row1_col4, #T_37489_row1_col6, #T_37489_row1_col7, #T_37489_row2_col2, #T_37489_row2_col5, #T_37489_row2_col6, #T_37489_row2_col7, #T_37489_row3_col1, #T_37489_row3_col3, #T_37489_row3_col4, #T_37489_row3_col5, #T_37489_row4_col0, #T_37489_row4_col1, #T_37489_row4_col3, #T_37489_row4_col4, #T_37489_row4_col5, #T_37489_row5_col0, #T_37489_row5_col2, #T_37489_row5_col3, #T_37489_row5_col4, #T_37489_row5_col5, #T_37489_row6_col1, #T_37489_row6_col2, #T_37489_row6_col6, #T_37489_row6_col7, #T_37489_row7_col1, #T_37489_row7_col2, #T_37489_row7_col6, #T_37489_row7_col7 {
#   color: None;
# }
# #T_37489_row0_col1, #T_37489_row0_col2, #T_37489_row0_col3, #T_37489_row0_col6, #T_37489_row0_col7, #T_37489_row1_col0, #T_37489_row1_col2, #T_37489_row1_col5, #T_37489_row2_col0, #T_37489_row2_col1, #T_37489_row2_col3, #T_37489_row2_col4, #T_37489_row3_col0, #T_37489_row3_col2, #T_37489_row3_col6, #T_37489_row3_col7, #T_37489_row4_col2, #T_37489_row4_col6, #T_37489_row4_col7, #T_37489_row5_col1, #T_37489_row5_col6, #T_37489_row5_col7, #T_37489_row6_col0, #T_37489_row6_col3, #T_37489_row6_col4, #T_37489_row6_col5, #T_37489_row7_col0, #T_37489_row7_col3, #T_37489_row7_col4, #T_37489_row7_col5 {
#   color: #FF3344;
# }
# </style>
# <table id="T_37489_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >survived</th>
#       <th class="col_heading level0 col1" >pclass</th>
#       <th class="col_heading level0 col2" >age</th>
#       <th class="col_heading level0 col3" >sibsp</th>
#       <th class="col_heading level0 col4" >parch</th>
#       <th class="col_heading level0 col5" >fare</th>
#       <th class="col_heading level0 col6" >adult_male</th>
#       <th class="col_heading level0 col7" >alone</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37489_level0_row0" class="row_heading level0 row0" >survived</th>
#       <td id="T_37489_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_37489_row0_col1" class="data row0 col1" >-0.34</td>
#       <td id="T_37489_row0_col2" class="data row0 col2" >-0.08</td>
#       <td id="T_37489_row0_col3" class="data row0 col3" >-0.04</td>
#       <td id="T_37489_row0_col4" class="data row0 col4" >0.08</td>
#       <td id="T_37489_row0_col5" class="data row0 col5" >0.26</td>
#       <td id="T_37489_row0_col6" class="data row0 col6" >-0.56</td>
#       <td id="T_37489_row0_col7" class="data row0 col7" >-0.20</td>
#     </tr>
#     <tr>
#       <th id="T_37489_level0_row1" class="row_heading level0 row1" >pclass</th>
#       <td id="T_37489_row1_col0" class="data row1 col0" >-0.34</td>
#       <td id="T_37489_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_37489_row1_col2" class="data row1 col2" >-0.37</td>
#       <td id="T_37489_row1_col3" class="data row1 col3" >0.08</td>
#       <td id="T_37489_row1_col4" class="data row1 col4" >0.02</td>
#       <td id="T_37489_row1_col5" class="data row1 col5" >-0.55</td>
#       <td id="T_37489_row1_col6" class="data row1 col6" >0.09</td>
#       <td id="T_37489_row1_col7" class="data row1 col7" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_37489_level0_row2" class="row_heading level0 row2" >age</th>
#       <td id="T_37489_row2_col0" class="data row2 col0" >-0.08</td>
#       <td id="T_37489_row2_col1" class="data row2 col1" >-0.37</td>
#       <td id="T_37489_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_37489_row2_col3" class="data row2 col3" >-0.31</td>
#       <td id="T_37489_row2_col4" class="data row2 col4" >-0.19</td>
#       <td id="T_37489_row2_col5" class="data row2 col5" >0.10</td>
#       <td id="T_37489_row2_col6" class="data row2 col6" >0.28</td>
#       <td id="T_37489_row2_col7" class="data row2 col7" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_37489_level0_row3" class="row_heading level0 row3" >sibsp</th>
#       <td id="T_37489_row3_col0" class="data row3 col0" >-0.04</td>
#       <td id="T_37489_row3_col1" class="data row3 col1" >0.08</td>
#       <td id="T_37489_row3_col2" class="data row3 col2" >-0.31</td>
#       <td id="T_37489_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_37489_row3_col4" class="data row3 col4" >0.41</td>
#       <td id="T_37489_row3_col5" class="data row3 col5" >0.16</td>
#       <td id="T_37489_row3_col6" class="data row3 col6" >-0.25</td>
#       <td id="T_37489_row3_col7" class="data row3 col7" >-0.58</td>
#     </tr>
#     <tr>
#       <th id="T_37489_level0_row4" class="row_heading level0 row4" >parch</th>
#       <td id="T_37489_row4_col0" class="data row4 col0" >0.08</td>
#       <td id="T_37489_row4_col1" class="data row4 col1" >0.02</td>
#       <td id="T_37489_row4_col2" class="data row4 col2" >-0.19</td>
#       <td id="T_37489_row4_col3" class="data row4 col3" >0.41</td>
#       <td id="T_37489_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_37489_row4_col5" class="data row4 col5" >0.22</td>
#       <td id="T_37489_row4_col6" class="data row4 col6" >-0.35</td>
#       <td id="T_37489_row4_col7" class="data row4 col7" >-0.58</td>
#     </tr>
#     <tr>
#       <th id="T_37489_level0_row5" class="row_heading level0 row5" >fare</th>
#       <td id="T_37489_row5_col0" class="data row5 col0" >0.26</td>
#       <td id="T_37489_row5_col1" class="data row5 col1" >-0.55</td>
#       <td id="T_37489_row5_col2" class="data row5 col2" >0.10</td>
#       <td id="T_37489_row5_col3" class="data row5 col3" >0.16</td>
#       <td id="T_37489_row5_col4" class="data row5 col4" >0.22</td>
#       <td id="T_37489_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_37489_row5_col6" class="data row5 col6" >-0.18</td>
#       <td id="T_37489_row5_col7" class="data row5 col7" >-0.27</td>
#     </tr>
#     <tr>
#       <th id="T_37489_level0_row6" class="row_heading level0 row6" >adult_male</th>
#       <td id="T_37489_row6_col0" class="data row6 col0" >-0.56</td>
#       <td id="T_37489_row6_col1" class="data row6 col1" >0.09</td>
#       <td id="T_37489_row6_col2" class="data row6 col2" >0.28</td>
#       <td id="T_37489_row6_col3" class="data row6 col3" >-0.25</td>
#       <td id="T_37489_row6_col4" class="data row6 col4" >-0.35</td>
#       <td id="T_37489_row6_col5" class="data row6 col5" >-0.18</td>
#       <td id="T_37489_row6_col6" class="data row6 col6" >1.00</td>
#       <td id="T_37489_row6_col7" class="data row6 col7" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_37489_level0_row7" class="row_heading level0 row7" >alone</th>
#       <td id="T_37489_row7_col0" class="data row7 col0" >-0.20</td>
#       <td id="T_37489_row7_col1" class="data row7 col1" >0.14</td>
#       <td id="T_37489_row7_col2" class="data row7 col2" >0.20</td>
#       <td id="T_37489_row7_col3" class="data row7 col3" >-0.58</td>
#       <td id="T_37489_row7_col4" class="data row7 col4" >-0.58</td>
#       <td id="T_37489_row7_col5" class="data row7 col5" >-0.27</td>
#       <td id="T_37489_row7_col6" class="data row7 col6" >0.40</td>
#       <td id="T_37489_row7_col7" class="data row7 col7" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
klib.dist_plot(df) # default representation of a distribution plot, other settings include fill_range, histogram, ...
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Density'>
