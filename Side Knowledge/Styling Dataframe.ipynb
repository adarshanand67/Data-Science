# %%
import numpy as np
import pandas as pd
#from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
# %matplotlib inline
# from autoviz.AutoViz_Class import AutoViz_Class
import seaborn as sns
import missingno as msno

# %config InlineBackend.figure_format = 'retina'
import bs4 as bs
import requests

import pyforest
import scipy.stats as stats
import keras as ks
# import tensorflow as tf
import cv2 as cv

import re
import os
import math
import datetime
import random
import time

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
sns.set(style='whitegrid', color_codes=True, font_scale=1.5, palette='plasma', font='Arial', rc={'figure.figsize':(8,6)})

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 0         16.99 1.01  Female     No   Sun  Dinner     2
# 1         10.34 1.66    Male     No   Sun  Dinner     3
# 2         21.01 3.50    Male     No   Sun  Dinner     3
# 3         23.68 3.31    Male     No   Sun  Dinner     2
# 4         24.59 3.61  Female     No   Sun  Dinner     4
# ..          ...  ...     ...    ...   ...     ...   ...
# 239       29.03 5.92    Male     No   Sat  Dinner     3
# 240       27.18 2.00  Female    Yes   Sat  Dinner     2
# 241       22.67 2.00    Male    Yes   Sat  Dinner     2
# 242       17.82 1.75    Male     No   Sat  Dinner     2
# 243       18.78 3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
format_dict = {
    'total_bill': '${:,.2f}',
    'tip': '${:,.2f}',
}

# %%
df_ = df.head().style.format(format_dict)
df__ = df_
df_
# Out:
# <style  type="text/css" >
# </style><table id="T_01bb7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_01bb7_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_01bb7_row0_col0" class="data row0 col0" >$16.99</td>
#                         <td id="T_01bb7_row0_col1" class="data row0 col1" >$1.01</td>
#                         <td id="T_01bb7_row0_col2" class="data row0 col2" >Female</td>
#                         <td id="T_01bb7_row0_col3" class="data row0 col3" >No</td>
# ...

# %%
df_.hide_index().highlight_max('size',color='red').highlight_min('size',color='green')
# Out:
# <style  type="text/css" >
# #T_01bb7_row0_col6,#T_01bb7_row3_col6{
#             background-color:  green;
#         }#T_01bb7_row4_col6{
#             background-color:  red;
#         }</style><table id="T_01bb7_" ><thead>    <tr>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_01bb7_row0_col0" class="data row0 col0" >$16.99</td>
#                         <td id="T_01bb7_row0_col1" class="data row0 col1" >$1.01</td>
#                         <td id="T_01bb7_row0_col2" class="data row0 col2" >Female</td>
# ...

# %%
df__
# Out:
# <style  type="text/css" >
# #T_01bb7_row0_col6,#T_01bb7_row3_col6{
#             background-color:  green;
#             background-color:  green;
#         }#T_01bb7_row4_col6{
#             background-color:  red;
#             background-color:  red;
#         }</style><table id="T_01bb7_" ><thead>    <tr>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_01bb7_row0_col0" class="data row0 col0" >$16.99</td>
#                         <td id="T_01bb7_row0_col1" class="data row0 col1" >$1.01</td>
# ...

# %%
df_.background_gradient(cmap='RdYlGn_r', subset=['tip'])
# Out:
# <style  type="text/css" >
# #T_01bb7_row0_col1{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_01bb7_row0_col6,#T_01bb7_row3_col6{
#             background-color:  green;
#             background-color:  green;
#             background-color:  green;
#         }#T_01bb7_row1_col1{
#             background-color:  #87cb67;
#             color:  #000000;
#         }#T_01bb7_row2_col1{
#             background-color:  #b91326;
#             color:  #f1f1f1;
#         }#T_01bb7_row3_col1{
#             background-color:  #db382b;
#             color:  #f1f1f1;
#         }#T_01bb7_row4_col1{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_01bb7_row4_col6{
#             background-color:  red;
#             background-color:  red;
#             background-color:  red;
# ...

# %%
df.style.background_gradient(cmap='RdYlGn_r', subset=['tip'])
# Out:
# <style  type="text/css" >
# #T_21e20_row0_col1,#T_21e20_row67_col1,#T_21e20_row92_col1,#T_21e20_row111_col1,#T_21e20_row236_col1{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_21e20_row1_col1,#T_21e20_row105_col1{
#             background-color:  #128a49;
#             color:  #000000;
#         }#T_21e20_row2_col1,#T_21e20_row18_col1,#T_21e20_row55_col1,#T_21e20_row91_col1,#T_21e20_row115_col1,#T_21e20_row140_col1,#T_21e20_row160_col1,#T_21e20_row182_col1,#T_21e20_row186_col1,#T_21e20_row188_col1{
#             background-color:  #98d368;
#             color:  #000000;
#         }#T_21e20_row3_col1{
#             background-color:  #89cc67;
#             color:  #000000;
#         }#T_21e20_row4_col1{
#             background-color:  #a0d669;
#             color:  #000000;
#         }#T_21e20_row5_col1{
#             background-color:  #ddf191;
#             color:  #000000;
# ...

# %%
df.head()
# Out:
#    total_bill  tip     sex smoker  day    time  size
# 0       16.99 1.01  Female     No  Sun  Dinner     2
# 1       10.34 1.66    Male     No  Sun  Dinner     3
# 2       21.01 3.50    Male     No  Sun  Dinner     3
# 3       23.68 3.31    Male     No  Sun  Dinner     2
# 4       24.59 3.61  Female     No  Sun  Dinner     4

# %%
df.style.hide_index().bar(subset=['total_bill']).set_properties(**{'width': '100px'}).set_caption('Total Bill')
# Out:
# <style  type="text/css" >
# #T_7c5a9_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.2%, transparent 29.2%);
#             width:  100px;
# ...
