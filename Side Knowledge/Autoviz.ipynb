# %%
# !pip install pyforest
# Out:
# ...
#   Using cached pyforest-1.1.0.tar.gz (15 kB)
# ...
#   Created wheel for pyforest: filename=pyforest-1.1.0-py2.py3-none-any.whl size=14607 sha256=67f095335f86e4fa7f23198a574fe84b356b45805a44318ccb751f8b08b85db5
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\d5\1a\3e\6193fe1c56168f5df4aef57d8411033ba4611881135d495727
# Successfully built pyforest
# ...

# %%
import pyforest
# %matplotlib inline

AV = AutoViz_Class()

# %%
filename = "../Datasets Seaborn/iris.csv"
sep = ","
dft = AV.AutoViz(
    filename,
    sep=",",
    depVar="",
    dfte=None,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
)
# Out:
# Shape of your Data Set loaded: (150, 6)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     6 Predictors classified...
#         1 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 10
# Time to run AutoViz = 4 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
