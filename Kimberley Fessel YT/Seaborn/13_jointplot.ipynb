# %% [markdown]
# # Seaborn: jointplot

# %%
import seaborn as sns

from matplotlib import pyplot as plt
import matplotlib

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
matplotlib.__version__
# Out:
# '3.4.3'

# %%
geyser = sns.load_dataset('geyser')

# %%
geyser.head()
# Out:
#    duration  waiting   kind
# 0     3.600       79   long
# 1     1.800       54  short
# 2     3.333       74   long
# 3     2.283       62  short
# 4     4.533       85   long

# %%
geyser.shape
# Out:
# (272, 3)

# %% [markdown]
# ## Intro Visuals

# %%
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)
plt.rc('axes', labelsize=14)

# %%
sns.set_style('white')

import numpy as np

my_color = '#643db8'

# %%
j = sns.jointplot(x='waiting', y='duration', data=geyser, color=my_color)

# %%
j = sns.jointplot(x='waiting', y='duration', 
                  data=geyser.iloc[:, :-1]+np.random.normal(0, 0.15, size=geyser.iloc[:, :-1].shape), #adding "jitter"
                  color='white')
j.plot_marginals(sns.rugplot, height=.5, color=my_color)
j.ax_joint.set_xlabel('')
j.ax_joint.set_ylabel('');

# %%
j = sns.jointplot(x='waiting', y='duration', data=geyser, color=my_color, kind='kde')
j.ax_joint.set_xlabel('')
j.ax_joint.set_ylabel('');

# %% [markdown]
# ### Thumbnail Figure

# %%
j = sns.jointplot(x='waiting', y='duration', 
                  data=geyser.iloc[:, :-1]+np.random.normal(0, 0.15, size=geyser.iloc[:, :-1].shape), #adding "jitter"
                  color= my_color)
j.plot_marginals(sns.rugplot, height=-.15, color='black', clip_on=False)
j.plot_joint(sns.kdeplot, color='black', levels=5)
j.ax_joint.set_xlabel('')
j.ax_joint.set_ylabel('')
j.ax_joint.set_ylim(0.5, 6)
j.ax_joint.set_xlim(30, 110);

# %%
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
plt.rc('axes', labelsize=10)

# %% [markdown]
# ## Basics

# %%
sns.set_style('darkgrid')

# %%
sns.jointplot(x=geyser.waiting, y=geyser.duration);

# %%
sns.jointplot(x='waiting', y='duration', data=geyser);

# %% [markdown]
# ## Plot Kinds
#
# There are currently six kinds of jointplots allowed in seaborn:
# 1. scatter (default)
# 2. kde
# 3. reg
# 4. hist
# 5. hex
# 6. resid

# %% [markdown]
# ### scatter (Default)

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='scatter'
             );

# %% [markdown]
# ### kde

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='kde'
             );

# %% [markdown]
# ### reg

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='reg'
             );

# %% [markdown]
# ### hist

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='hist'
             );

# %% [markdown]
# ### Returns JointGrid

# %%
g = sns.jointplot(x='waiting', y='duration', data=geyser);

# %%
type(g)
# Out:
# seaborn.axisgrid.JointGrid

# %%
g.plot_joint(sns.kdeplot, color='gray', levels=5);

# %% [markdown]
# ## Categorical Variables

# %%
geyser.head()
# Out:
#    duration  waiting   kind
# 0     3.600       79   long
# 1     1.800       54  short
# 2     3.333       74   long
# 3     2.283       62  short
# 4     4.533       85   long

# %% [markdown]
# ### hue

# %%
sns.jointplot(x='waiting', y='duration', data=geyser);

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              hue='kind'
             );

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              hue='kind',
              kind='kde'
             );

# %% [markdown]
# ## Styling

# %% [markdown]
# ### color, palette

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              color='green'
             );

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              hue='kind',
              palette='autumn'
             );

# %% [markdown]
# ### height, space, ratio

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              height=8,   #Default: 6
              space=0.1,  #Default: 0.2
              ratio=2     #Default: 5
             );

# %% [markdown]
# ### joint_kws
#
# Joint keywords should match the figure type in the middle of the jointplot.

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              joint_kws={'marker': 5}
             );

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='reg',
              joint_kws={'ci': None, 'order': 2}
             );

# %% [markdown]
# ### marginal_kws
#
# Marginal keywords should match the type of plot for the marginal distribution plots (the outside plots).

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              marginal_kws={'color': 'xkcd:golden'}
             );

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='kde',
              marginal_kws={'lw': 4, 'shade': True}
             );

# %% [markdown]
# Jointplot for iris dataset

# %%
df =sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.jointplot(x='sepal_width', y='sepal_length', data=df,hue='species')

# %%
sns.jointplot(x='sepal_width', y='sepal_length', data=df,kind='hex')

# %%
sns.jointplot(x='sepal_width', y='sepal_length', data=df,kind='reg')

# %%
sns.jointplot(x='sepal_width', y='sepal_length', data=df,kind='hist')

# %% [markdown]
# JOintplot helps in visualizing the relationship between two variables. Both univariate and bivariate plots are possible in the same figure.

# %%
sns.jointplot(x='sepal_width', y='sepal_length', data=df,hue='species',kind='kde')

# %%
sns.jointplot(x='sepal_width', y='sepal_length', data=df,hue='species',kind='hist',palette='plasma')
