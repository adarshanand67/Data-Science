# %% [markdown]
# # Diamonds dataset
# - price price in US dollars (\$326 — \$18,823)
#
# - carat weight of the diamond (0.2–5.01)
#
# - cut quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# - color diamond colour, from J (worst) to D (best)
#
# - clarity a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# - x length in mm (0–10.74)
#
# - y width in mm (0–58.9)
#
# - z depth in mm (0–31.8)
#
# - depth total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43–79)
#
# - table width of top of diamond relative to widest point (43–95)

# %% [markdown]
# # Seaborn: scatterplot

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
diamonds = sns.load_dataset('diamonds')

diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds = diamonds[
    diamonds.cut.isin(['Premium', 'Ideal']) &
    diamonds['color'].isin(['D', 'E'])
].sample(n=100,random_state=42)

# %%
diamonds
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 33546   0.35    Ideal     D     VS2   62.4   55.0    829  4.48  4.52  2.81
# 6094    0.81    Ideal     E     VS2   61.5   57.0   3975  6.00  6.06  3.71
# 51459   0.72  Premium     E     SI2   62.6   59.0   2376  5.74  5.70  3.58
# 12465   1.03    Ideal     D     SI1   62.3   56.0   5249  6.51  6.45  4.04
# 15002   1.00    Ideal     E     VS2   62.0   55.0   6043  6.42  6.38  3.97
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 47639   0.51    Ideal     D     VS2   61.9   55.0   1882  5.13  5.11  3.17
# 484     0.73  Premium     E     SI1   62.2   59.0   2821  5.77  5.68  3.56
# 6372    0.32    Ideal     E     SI2   62.7   55.0    576  4.42  4.39  2.76
# 46069   0.46    Ideal     E    VVS2   62.6   55.0   1736  4.95  4.92  3.09
# 15078   1.07    Ideal     E     SI2   62.5   57.0   6060  6.56  6.50  4.08
#
# [100 rows x 10 columns]

# %%
sns.heatmap(diamonds.isnull(), cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Intro Visuals

# %%
import pandas as pd
import numpy as np

# %%
sns.set_style('white')
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)

# %%
blue, orange, green, red = sns.color_palette()[:4]

# %%
pts_x = [1] #, 2, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1] #, 3, 2.5, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic1.svg')
# Out:
# /home/adarshanand67/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts_x = [1, 2] #, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3] #, 2.5, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic2.svg')
# Out:
# /home/adarshanand67/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts_x = [1, 2, 1.5] #, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5] #, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic3.svg')
# Out:
# /home/adarshanand67/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts_x = [1, 2, 1.5, 4, 3, 2.5] #, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5, 3, 3.5, 2] #, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic4.svg')

# %%
pts_x = [1, 2, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5] #, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5, 3, 3.5, 2, 2.5, 1.8, 4] #, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic5.svg')

# %%
pts_x = [1, 2, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasicFull.svg')

# %%
for x,y in zip(pts_x, pts_y):
    print((x, y))

# %%
cat = [0, 0, 1, 1, 0, 0, 1, 0, 1, 1, 0, 0, 1, 1]

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=200, hue=cat, alpha=0.7, edgecolor='black', palette={0: 'xkcd:crimson', 1: '#3d9f98'})
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_byHue.png')

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=200, style=cat, alpha=0.7, edgecolor='black', color='xkcd:crimson')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_byStyle.png')

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, size=cat, alpha=0.7, edgecolor='black', color='xkcd:crimson', sizes=[50, 300])
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_bySize.png')

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, size=cat, hue=cat, style=cat,
                alpha=0.7, edgecolor='black',  
                sizes=[100, 300],
                palette={0: 'xkcd:crimson', 1: '#3d9f98'}
               )
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_byAll.png')

# %%
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# ## Basics

# %%
sns.set_style('white')

# %%
sns.scatterplot(diamonds.carat, diamonds.price);
# Out:
# /home/adarshanand67/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(x='carat', y='price', data=diamonds);

# %%
sns.scatterplot(x='x', y='y', data=diamonds);

# %% [markdown]
# ## Semantic Variables

# %%
sns.set_style('darkgrid')

# %% [markdown]
# ### hue

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
                data=diamonds
               );

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
                data=diamonds,
                palette='rocket'
               );

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
                data=diamonds,
                palette = 'rocket',
                # hue_order=['Good', 'Premium']
               );

# %% [markdown]
# #### Continuous Variable

# %%
sns.scatterplot(x='carat', y='price', hue='depth',
                data=diamonds
               );

# %% [markdown]
# ### style

# %%
sns.scatterplot(x='carat', y='price', style='cut',
                data=diamonds,
                s=100
               );

# %% [markdown]
# ### size

# %%
sns.scatterplot(x='carat', y='price', size='cut',
                data=diamonds,alpha=0.7,
               );

# %%
sns.scatterplot(x='carat', y='price', size='cut',
                data=diamonds, 
               );

# %%
sns.scatterplot(x='carat', y='price', size='depth',
                data=diamonds
               );

# %% [markdown]
# ### hue + style + size

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut', # split the diamonds by cut
                style='cut', # style the diamonds by cut
                data=diamonds,
                s=100
               );

# %%
# move the legend outside of the plot
sns.scatterplot(x='carat', y='price',
                hue='cut',
                style='color',
                data=diamonds,
                s=100,
                );
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut', 
                style='color',
                size='depth',
                data=diamonds)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.);

# %% [markdown]
# ## Additional Styling

# %% [markdown]
# ### alpha

# %%
sns.scatterplot(x='carat', y='price', 
                data=diamonds,
                s=100,
                alpha=0.6
               );

# %% [markdown]
# ### marker styling
#
# Check the [matplotlib scatter](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html) and the [marker style docs](https://matplotlib.org/api/_as_gen/matplotlib.markers.MarkerStyle.html#matplotlib.markers.MarkerStyle) for more styling of the markers themselves

# %%
sns.scatterplot(x='carat', y='price', 
                data=diamonds, 
                s=200,
                marker='*'
               );

# %%
sns.scatterplot(x='carat', y='price', 
                data=diamonds, 
                s=200, 
                marker='*',
                edgecolor='black'
               );
