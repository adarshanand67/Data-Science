# %% [markdown]
# # Seaborn: histplot

# %%
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
penguins.dropna(inplace=True)

# %%
penguins.shape
# Out:
# (333, 7)

# %% [markdown]
# ## Intro Visuals

# %% [markdown]
# `distplot` has now been deprecated.  Switch to `histplot` for histogram plots.

# %%
sns.distplot(penguins.flipper_length_mm);
# Out:
# /home/adarshanand67/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from matplotlib import pyplot as plt

# %%
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)
plt.rc('axes', labelsize=14)

# %%
sns.set_style('white')

# %%
sns.histplot(penguins.flipper_length_mm,kde=True)
sns.despine()
plt.xlabel('')
plt.tight_layout();

# %%
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)

# %%
plt.figure(figsize=(7,4))
sns.histplot(penguins.flipper_length_mm, alpha=0.6,kde=True)

sns.despine(left=True)
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
plt.tight_layout();

# %%
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
plt.rc('axes', labelsize=10)

# %% [markdown]
# ## Basics

# %%
sns.set_style('darkgrid')

# %%
sns.histplot(penguins.flipper_length_mm);

# %%
sns.histplot(y = 'flipper_length_mm', data=penguins);

# %% [markdown]
# ### `kde`

# %%
sns.histplot(x='flipper_length_mm', data=penguins,
             kde=True
             );

# %% [markdown]
# ### `bins`

# %%
sns.histplot(x='flipper_length_mm', data=penguins, bins=20);

# %% [markdown]
# ### `binwidth` and `binrange`

# %%
sns.histplot(x='flipper_length_mm', data=penguins, 
             binwidth=10, binrange=(180,250),
             kde=True
            );

# %% [markdown]
# ## Statistics

# %% [markdown]
# ### `stat`

# %%
sns.histplot(x='flipper_length_mm', data=penguins,
             stat='count'
            );

# %% [markdown]
# **density** - AREA of histogram sums to one

# %%
sns.histplot(x='flipper_length_mm', data=penguins,
             stat='density'
            );
# Probablity density function

# %% [markdown]
# **probability** - HEIGHT of histogram bars to one

# %%
sns.histplot(x='flipper_length_mm', data=penguins,
             stat='probability'
            );
# Probablity that the flipper length is greater in that space

# %% [markdown]
# ### `cumulative`

# %%
sns.histplot(x='flipper_length_mm', data=penguins,
             stat='probability', fill=False, element='step',
             cumulative=True
            );

# %% [markdown]
# ## Categorical Variables

# %% [markdown]
# ### `hue`

# %%
sns.histplot(x='flipper_length_mm', data=penguins, hue='species');

# %% [markdown]
# ### `element`

# %%
sns.histplot(x='flipper_length_mm', data=penguins, 
             hue='species',
             element='step'
            );

# %%
sns.histplot(x='flipper_length_mm', data=penguins, 
             hue='species',
             element='poly'
            );
# Creates polygons

# %% [markdown]
# ### `multiple`

# %%
sns.histplot(x='flipper_length_mm', data=penguins, 
             hue='species', 
             multiple='stack'
            );

# %%
sns.histplot(x='flipper_length_mm', data=penguins, 
             hue='species', 
             multiple='fill'
            ); 

# Fill argument is used to fill the polygons , scaled upto 1.

# %% [markdown]
# **BONUS Example**: `multiple="dodge"`

# %%
sns.histplot(x='species', data=penguins, 
             hue='island', 
             multiple='dodge',
             shrink=0.8
            );

# %% [markdown]
# ## Bivariate Histplot

# %%
sns.set_style('whitegrid')

# %%
sns.histplot(x='flipper_length_mm', y='bill_length_mm', data=penguins);

# %% [markdown]
# ### `cbar`

# %%
sns.histplot(x='culmen_length_mm', y='culmen_depth_mm', data=penguins,
             cbar=True
            );

# %% [markdown]
# ### `hue`

# %%
sns.histplot(x='bill_length_mm', y='bill_depth_mm', data=penguins,
             hue='species',cbar=True,
            )
# Move legend out
plt.legend(loc='upper right');
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Discrete color map

# %%
sns.histplot(x='culmen_length_mm', y='species', data=penguins,
             hue='species'
            );

# %% [markdown]
# ## Styling

# %% [markdown]
# ### `shrink`

# %%
sns.histplot(x='species',  hue='sex', multiple='dodge', data=penguins,
             shrink=0.8
            );

# %% [markdown]
# ### `color`, `palette`

# %%
sns.histplot(x='bill_depth_mm', data=penguins,
             color='pink'
            );

# %%
sns.histplot(x='species',  hue='sex', multiple='dodge', data=penguins,shrink=0.8, palette='bone');

# %% [markdown]
# ### `fill`

# %%
sns.histplot(x='bill_depth_mm', data=penguins,
            fill=False
            );
